# %%
#Libraries needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('train.csv', sep=',')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
plt.scatter(df['YearBuilt'], df['SalePrice'])

# %%
df['SalePrice'].describe()
sns.distplot(df['SalePrice'])

# %%
data = pd.concat([df['SalePrice'], df['YearBuilt']], axis=1)
data.plot.scatter(x='YearBuilt', y='SalePrice', ylim=(0,800000))

# %%
plt.bar(df['MSZoning'], df['SalePrice'])
(df['MSZoning']).value_counts()

# Inference: Majority of the properties are residential low density
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
df['SaleCondition'].describe()

plt.bar(df['SaleCondition'], df['SalePrice'])

(df['SaleCondition']).value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
plt.scatter(df['LotArea'], df['SalePrice'])

# %%
plt.scatter(df['Street'], df['SalePrice'])

# %%
plt.scatter(df['HouseStyle'], df['SalePrice'])

# %%
plt.scatter(df['OverallQual'], df['SalePrice'])

# %%
plt.scatter(df['SaleType'], df['SalePrice'])

plt.bar(df['SaleType'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.scatter(df['YrSold'], df['SalePrice'])

# %%
plt.scatter(df['MoSold'], df['SalePrice'])
#plt.scatter(x='MoSold', y='SalePrice', ylim=(0,800000))

df['MoSold'].value_counts()
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64

# %%
num = [x for x in df.columns if df.dtypes[x] != 'object']
print (num)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
cat = [x for x in df.columns if df.dtypes[x] == 'object']
print (cat)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
miss = df.isnull().sum().sort_values(ascending=False)
miss

'''remove_missing=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu','LotFrontage']
df1 = df.copy()
df1.drop(missing_list, axis=1) '''
# Out:
# "remove_missing=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu','LotFrontage']\ndf1 = df.copy()\ndf1.drop(missing_list, axis=1) "

# %%
data = pd.concat([df['SalePrice'], df['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0,800000))

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
#df.plot()

# %%
data.corr()
# Out:
#            SalePrice  GrLivArea
# SalePrice   1.000000   0.708624
# GrLivArea   0.708624   1.000000

# %%
data.boxplot('GrLivArea', return_type = 'axes')

# %%
plt.scatter(df['Neighborhood'], df['SalePrice'])

# %%
plt.bar(df['Neighborhood'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.bar(df['Condition1'], df['SalePrice'])

df['Condition1'].value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
plt.bar(df['BldgType'], df['SalePrice'])

df['BldgType'].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
plt.scatter(df['BldgType'], df['SalePrice'])

# %%
plt.bar(df['HouseStyle'], df['SalePrice'])

df['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
plt.scatter(df['HouseStyle'], df['SalePrice'])

# %%
plt.bar(df['ExterCond'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.scatter(df['ExterCond'], df['SalePrice'])

# %%
plt.bar(df['BsmtQual'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.bar(df['BsmtCond'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.bar(df['BsmtFinType1'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.scatter(df['BsmtFinSF1'], df['SalePrice'])

# %%
plt.bar(df['KitchenQual'], df['SalePrice'])
# Out:
# <Container object of 1460 artists>

# %%
plt.scatter(df['KitchenQual'], df['SalePrice'])

# %%
df_iowa = df.copy()

# Select columns needed from Iowa DS 
df_iowa = df_iowa[['SalePrice', 'YearBuilt', 'HouseStyle','Neighborhood', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath','BedroomAbvGr','TotalBsmtSF', 'GrLivArea']]

# half bath is 0.5
df_iowa['hbath'] = df_iowa['BsmtHalfBath'] + df_iowa['HalfBath']  
df_iowa['hbath'] = np.where(df_iowa['hbath'] > 0, df_iowa['hbath']/2 , 0)
df_iowa['bath'] = df_iowa['BsmtFullBath'] + df_iowa['FullBath'] + df_iowa['hbath']

# sum up basement and other living area to get total sq. feet
df_iowa['Sq. Ft.'] = df_iowa['TotalBsmtSF'] + df_iowa['GrLivArea']

#Remove unwanted columns now that we have a new column for bath in DF and we have sq. feet
df_iowa.drop(['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath','hbath','TotalBsmtSF', 'GrLivArea'], axis =1, inplace = True)

# %%
# Renaming the columns on Iowa df to keep them uniform across all data sets
df_iowa.columns = ['SalePrice', 'YearBuilt','HouseStyle','Neighborhood','Bed','Bath','Sq. Ft.']
df_iowa
# Out:
#       SalePrice  YearBuilt HouseStyle Neighborhood  Bed  Bath  Sq. Ft.
# 0        208500       2003     2Story      CollgCr    3   3.5     2566
# 1        181500       1976     1Story      Veenker    3   2.5     2524
# 2        223500       2001     2Story      CollgCr    3   3.5     2706
# 3        140000       1915     2Story      Crawfor    3   2.0     2473
# 4        250000       2000     2Story      NoRidge    4   3.5     3343
# 5        143000       1993     1.5Fin      Mitchel    1   2.5     2158
# 6        307000       2004     1Story      Somerst    3   3.0     3380
# 7        200000       1973     2Story       NWAmes    3   3.5     3197
# 8        129900       1931     1.5Fin      OldTown    2   2.0     2726
# 9        118000       1939     1.5Unf      BrkSide    2   2.0     2068
# 10       129500       1965     1Story       Sawyer    3   2.0     2080
# 11       345000       2005     2Story      NridgHt    4   4.0     3499
# ...

# %%
df_iowa['New_Price/SQ.Ft'] = df_iowa['SalePrice']/df_iowa['Sq. Ft.']


plt.scatter(df_iowa['YearBuilt'], df_iowa['New_Price/SQ.Ft'], alpha = 0.5 )
plt.ylabel('Price/Sq.Ft')
plt.xlabel('YearBuilt')
plt.title('Year Built vs. Price/Sq.ft')
# Out:
# Text(0.5,1,'Year Built vs. Price/Sq.ft')

# %%
df_iowa

# %%
'''
names = df_iowa.columns
correlations = df_iowa.corr()
# plot correlation matrix

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,8,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()
'''

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df_iowa.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
df_iowa.hist()

# %%
df_iowa.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
plt.show()

# %%
df_iowa.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.show()

# %%
df_iowa['New_Price/SQ.Ft'].describe()

# %%
#2nd Dataset
df_ca=pd.read_csv('RealEstate.csv', sep=',')

#MLS and Status not needed for our analysis
df_ca = df_ca[['Price', 'Location','Bedrooms','Bathrooms', 'Size', 'Price/SQ.Ft']]
df_ca.columns = ['SalePrice','Neighborhood','Bed','Bath','Sq. Ft.','Price/SQ.Ft']
df_ca
# Out:
#      SalePrice         Neighborhood  Bed  Bath  Sq. Ft.  Price/SQ.Ft
# 0     795000.0        Arroyo Grande    3     3     2371       335.30
# 1     399000.0          Paso Robles    4     3     2818       141.59
# 2     545000.0          Paso Robles    4     3     3032       179.75
# 3     909000.0            Morro Bay    4     4     3540       256.78
# 4     109900.0   Santa Maria-Orcutt    3     1     1249        87.99
# 5     324900.0               Oceano    3     3     1800       180.50
# 6     192900.0   Santa Maria-Orcutt    4     2     1603       120.34
# 7     215000.0   Santa Maria-Orcutt    3     2     1450       148.28
# 8     999000.0            Morro Bay    4     3     3360       297.32
# 9     319000.0           Atascadero    3     2     1323       241.12
# 10    350000.0   Santa Maria-Orcutt    3     2     1750       200.00
# 11    249000.0   Santa Maria-Orcutt    3     2     1400       177.86
# 12    299000.0        Arroyo Grande    2     2     1257       237.87
# ...

# %%
#3rd Dataset
new_file = pd.ExcelFile("woodard.xls")
new_file.sheet_names
[u'Sheet1', u'Sheet2', u'Sheet3']
df_nc = new_file.parse("Sheet1")
df_nc = df_nc[['Total $','Year Built','Sq. Ft.','Story','Zip','No. Baths']]
df_nc.columns = ['SalePrice','YearBuilt','Sq. Ft.','HouseStyle','Zip','Bath']
df_nc
# Out:
#     SalePrice  YearBuilt  Sq. Ft.  HouseStyle    Zip  Bath
# 0      203200       1990     2102        1.00  27603   NaN
# 1      119096       1986     1740        1.50  27604   3.0
# 2       71666       1955      795        1.00  27610   1.0
# 3      131103       1983     1152        1.00  27616   2.0
# 4     4904102       2003     1404        1.00  27519   2.0
# 5      144452       1967     1752        1.00  27604   1.5
# 6      496425       1924     1829        1.50  27607   3.0
# 7      169187       1980     1246        1.00  27511   2.0
# 8      243092       1989     2264        2.00  27609   2.5
# 9      432516       1994     3483        2.50  27519   3.0
# 10     192794       1970     1646        1.50  27606   2.0
# 11      58116       1990     1188        1.00  27610   1.0
# 12     394694       1930     1657        1.50  27604   1.0
# 13     135298       1973     1383        1.00  27545   2.0
# 14     124355       1985     1212        1.50  27545   2.0
# ...

# %%
df_final = pd.concat([df_iowa,df_ca,df_nc], axis=0, ignore_index=True)
df_final

df_final.replace('', np.NaN)
'''
df_final.to_csv('subha_merged_file.csv', index=False)
df_final['YearBuilt'] = df_final['YearBuilt'].fillna(0).astype(np.int64)
df_final.head() '''
# Out:
# "\ndf_final.to_csv('subha_merged_file.csv', index=False)\ndf_final['YearBuilt'] = df_final['YearBuilt'].fillna(0).astype(np.int64)\ndf_final.head() "

# %%
# Year Built - Sanity check: Pass; No record after 2011

#(df_final['YearBuilt']>=2010).any()

(df_final['YearBuilt']>=2011).any()

df_final['YearBuilt'].describe()

# %%
df_final['New_Price/SQ.Ft'] = df_final['SalePrice']/df_final['Sq. Ft.']
#df_final[['New_Price/SQ.Ft', 'Price/SQ.Ft']].assign(NE= df_final['New_Price/SQ.Ft'] != df_final['Price/SQ.Ft'])
df_final['new_col'] = df_final['New_Price/SQ.Ft'] != df_final['Price/SQ.Ft']
df_final.assign(new_col = df_final['New_Price/SQ.Ft'] != df_final['Price/SQ.Ft'])

#df_final([df_final['new_col']] == False)
 
df_final.loc[df_final['new_col'] != False]

# %%
data = pd.concat([df_final['SalePrice'], df_final['YearBuilt']], axis=1)
data.plot.scatter(x='YearBuilt', y='SalePrice', ylim=(0,800000), xlim=(1860,2015))

# %%
data.boxplot('YearBuilt', return_type = 'axes')

# %%
ax = df_iowa['SalePrice'].plot()

df_nc['SalePrice'].plot(ax=ax)

# %%
ax = df_iowa['YearBuilt'].plot()

df_nc['YearBuilt'].plot(ax=ax)

# %%
data = pd.concat([df_final['SalePrice'], df_final['YearBuilt']], axis=1)
data.plot.scatter(x='YearBuilt', y='SalePrice', ylim=(0,800000), xlim=(1860,2015), logy = True)

# %%
df_final['log_SalePrice'] = np.log(df_final['SalePrice'])
data = pd.concat([df_final['log_SalePrice'], df_final['YearBuilt']], axis=1)
data.plot.scatter(x='YearBuilt', y='log_SalePrice', ylim=(0,800000), xlim=(1860,2015))

# %%
plt.scatter(df_final['log_SalePrice'], df_final['YearBuilt'], alpha = 0.1 , color = 'b')
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
y = df_final['log_SalePrice']
x = df_final['YearBuilt']
fig, ax = plt.subplots()
ax.plot(x, y, markerfacecolor='CornflowerBlue', markeredgecolor='green')
#ax.set_xlim([1820,2011])
ax.set_xlim(xmin = 1860, xmax = 2011)

# %%
y = df_final['log_SalePrice']
x = df_final['YearBuilt']
fig, ax = plt.subplots()
ax.scatter(x, y, c = 'blue')
ax.scatter(x, y, c = 'green')
   
#ax.set_xlim([1820,2011])
ax.set_xlim(xmin = 1860, xmax = 2015)

# %%
df_final.index

# %%
import matplotlib.cm as cm
y = df_final['log_SalePrice']
x = df_final['YearBuilt']
fig, ax = plt.subplots()
ax.scatter(x, y, c = df.iloc[0:1460,0], cmap = cm)
#ax.scatter(x, y, c = 'green')
   
#ax.set_xlim([1820,2011])
ax.set_xlim(xmin = 1860, xmax = 2015)

# %%
df_final.loc[0:1460]

# %%
y = df_final['log_SalePrice']
x = df_final['YearBuilt']
fig, ax = plt.subplots()
#colors = np.where([df_final.loc[0:1460]],'r','-')
#colors[df_final.loc[1461:2341]] = 'g'
#colors = np.where(df_final.index[df['SalePrice'] == 0, 'r', '-'])

#colors = np.where(df_final[df.iloc[] >= 0 & df_final[df.iloc[] < 1461, 'r','-')
#colors[df_final.index[df['SalePrice'] == 1]] = 'g'
#colors[df_final.index[df['SalePrice'] > 1460 & df['SalePrice'] <= 1460]
#ax.scatter(x, y, c = colors)
#ax.scatter(x, y, c = 'green')
cm = plt.cm.get_cmap('RdYlBu')
ax.scatter (x,y, c = df_final.index <= 1461, cmap = cm)                                                     
   
#ax.set_xlim([1820,2011])
ax.set_xlim(xmin = 1860, xmax = 2015)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-590b09bb300b> in <module>()
# ----> 1 y = df_final['log_SalePrice']
#       2 x = df_final['YearBuilt']
#       3 fig, ax = plt.subplots()
#       4 #colors = np.where([df_final.loc[0:1460]],'r','-')
#       5 #colors[df_final.loc[1461:2341]] = 'g'
#
# NameError: name 'df_final' is not defined

# %%
## working chart - final
plt.figure(figsize=(12,10))
plt.subplots()

for title, group in df_final[df_final['Dataset'] != 'CA'].groupby('Dataset'):
    plt.plot(group['YearBuilt'], np.log(group['SalePrice']), \
                alpha=.75, linestyle ='', ms=15, marker='.', label=title)
    plt.ylabel('Log Sale Price')
    plt.xlabel('Year Built')
    plt.title('Log Sale Price vs Year Built in NC and IA Data Set')
    title_dict = {'IA': 'Iowa', 'NC': 'North Carolina'}
    print(title_dict[title], 'has correlation of', np.corrcoef(group.LotArea, np.log(group.SalePrice))[0, 1])
plt.legend()

# %%
df_final.index

# %%
y = df_final['log_SalePrice']
x = df_final['YearBuilt']
fig, ax = plt.subplots()
colors = df_final.index == 

cm = plt.cm.get_cmap('RdYlBu')
ax.scatter (df_final['log_SalePrice'], df_final['YearBuilt'], c = df_final.index <= 1461, cmap = cm)                                                     
   
#ax.set_xlim([1820,2011])
ax.set_xlim(xmin = 1860, xmax = 2015)

# %%
plt.plot(df_final.mask(df_final.apply(lambda x: x.index < 1461)), color='blue')
plt.plot(df_final.mask(df_final.apply(lambda x: x.index >= 1461 and x.index < 2241)), color='green')
plt.show()
